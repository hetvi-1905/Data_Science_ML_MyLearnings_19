# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %% [markdown]
# ## without train and split

# %%
df = pd.read_csv("homeprices.csv")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("area (sqr ft)")
plt.ylabel("price (US$)")
plt.scatter(df.area,df.price,color="red",marker="+")

# %%
# linear regression
reg = linear_model.LinearRegression()

reg.fit(df[['area']],df.price)   # reg.fit(X,y)
# Out:
# LinearRegression()

# %%
# reg.predict(np.array([3300]).reshape(1, 1))     or
reg.predict([[3300]])
# Out:
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
# y = mx+c
ans = 135.78767123 * 3300 + 180616.43835616432
ans # --> ans is y = price
# Out:
# 628715.7534151643

# %%
# %matplotlib inline
plt.xlabel("area (sqr ft)")
plt.ylabel("price (US$)")
plt.scatter(df.area,df.price,color="red",marker="+")

plt.plot(df.area, reg.predict(df[["area"]]),color="blue")   # Mimp
# plt.plot(df.area,df.price,color="blue")  ---> wrong it only connects all prices points but we want regression best fit line so it wont work

# %%
# How to predict price when only area are given in csv file

d = pd.read_csv("homeprices2.csv")
d
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000

# %%
p = reg.predict(d)  # gives prices of the areas in homeprices2 file by following the trained data model

# %%
d["prices"] = p   # makes new col for prices in which predicted prices are stored
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205])

# %%
d = pd.read_csv("homeprices2.csv")

# %%
d
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000

# %%
d.to_csv("prediction_of_homeprices2.csv",index=False)  # make new csv file in which prices along with area are filled

# %% [markdown]
# ## Train and Test Split

# %%
df2 = pd.read_csv("homeprices.csv")
df2
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# splitting dataset into train and test data

X = df2.iloc[:,:-1]
y = df2.iloc[:,-1]

# %%
X
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
y
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.4 , random_state = 0)

# %%
X_test
# Out:
#    area
# 2  3200
# 0  2600

# %%
from sklearn.linear_model import LinearRegression
slr = LinearRegression()
slr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
output_predicted = slr.predict(X_test) 
output_predicted
# Out:
# array([602500., 505000.])

# %%
y_test
# Out:
# 2    610000
# 0    550000
# Name: price, dtype: int64

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,output_predicted)
score
# Out:
# -0.15625000000000666
